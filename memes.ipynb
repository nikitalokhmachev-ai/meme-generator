# %%
from utils.meme_captioner import MemeCaptioner
from IPython.display import display

# %%
mc = MemeCaptioner()

# %%
urls = [ 
    "https://psv4.userapi.com/c856228/u124285623/docs/d5/35dc3c63f737/IMG_20200626_195101.jpg?extra=sRzmKiJtTL-VMORO7xajmvd9ZRewNrjnbEZI4SuoRBLCG-Ull5_8_JN10by9EJ90z_HtGydWy9FCtGhrd2cv6VRxlzbCLmXE_KZNBe2V3g1phP2P-HP9s7QD5Lc1fiLxSzdeeo1-tfZL-A5aFQOnUBA",
    "https://psv4.userapi.com/c856420/u124285623/docs/d15/51dd40cb5e93/IMG_20200626_203816.jpg?extra=fWhyb29we0uAufbFKciYxScO97NlBFSygdfnGqmznCIdPDZPrCJVQUjLXCAd6DREam83Yz9rGMtRTbFIYsxJYbYxdzSriMtPhwV74enkaXYgVNGyGAi4uqrpAMgRCpIWHd_gR1yQYG6YNbv2rEOUO1o",
    "https://sun1-99.userapi.com/Qu6QvQnxTUDXtrgYo-HmTcYfDpPGdL4gOyGphA/pvmptDU12xg.jpg",
    "https://sun1-22.userapi.com/fmbAhR-SNkNS7xB-vIXbjpcu3xSMSX1PfEtZDw/pJovjkU-Rto.jpg",
    "https://sun1-94.userapi.com/yJfJdLnAhQvuWVVohkBqk6nM2hB7c-xgHaPipQ/-l9JNNUSs-k.jpg",
    "https://sun1-22.userapi.com/QQFVNiiDz8VS7jjapf0JuHd3Co5nkxplB5pAzw/apaVFCCw1HY.jpg"
]

# %%
for url in urls:
    display(mc.generate_caption(url))
# Out:
# <PIL.Image.Image image mode=RGB size=546x445 at 0x2069205EFC8>
# <PIL.Image.Image image mode=RGB size=554x475 at 0x2069206D208>
# <PIL.Image.Image image mode=RGB size=500x469 at 0x206920A3948>
# <PIL.Image.Image image mode=RGB size=532x664 at 0x206900899C8>
# <PIL.Image.Image image mode=RGB size=500x751 at 0x2069204BFC8>
# <PIL.Image.Image image mode=RGB size=532x570 at 0x20692089B88>
